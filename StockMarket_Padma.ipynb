# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Lets read in the input
stock_df = pd.read_csv("C:\ddrive\PADMA\DataScience\stocks-us-adjClose.csv")
stock_df.head()
# Out:
#   compiled from Yahoo! Finance data by Matt Borthwick        ED        DD  \
# 0                                           1/2/1970   0.307997  0.000480
# 1                                           1/5/1970   0.320831  0.000481
# 2                                           1/6/1970   0.316553  0.000477
# 3                                           1/7/1970   0.312275  0.000475
# 4                                           1/8/1970   0.312275  0.000469
#
#         CVX        FL       CAT        IP  SJW   F  LLY ...   EXTN  VYGR  ACG  \
# 0  0.582503  1.857836  1.475225  1.808415  NaN NaN  NaN ...    NaN   NaN  NaN
# 1  0.585290  1.839623  1.470783  1.873423  NaN NaN  NaN ...    NaN   NaN  NaN
# 2  0.576929  1.845694  1.435234  1.855694  NaN NaN  NaN ...    NaN   NaN  NaN
# 3  0.575535  1.809266  1.390800  1.814324  NaN NaN  NaN ...    NaN   NaN  NaN
# 4  0.586683  1.821408  1.395244  1.832054  NaN NaN  NaN ...    NaN   NaN  NaN
#
#    MIME  TCRZ  MCX  EDIT  LMHA  UA  BTU
# ...

# %%
stock_df.describe()
# Out:
#                  ED            DD           CVX            FL           CAT  \
# count  12032.000000  12031.000000  12032.000000  12032.000000  12032.000000
# mean      16.221365      4.657988     25.838805     13.652820     22.134786
# std       19.088316     16.842472     32.410597     15.029301     28.448792
# min        0.092676      0.000419      0.443472      0.505457      1.075315
# 25%        0.980461      0.000945      2.323380      2.445677      2.826035
# 50%        8.586078      0.003967      9.601468     10.450088      5.716164
# 75%       25.608041      0.014223     38.221566     16.793522     32.422255
# max       85.529999     85.106949    117.790649     78.051933    118.300003
#
#                  IP           SJW             F           LLY           AVP  \
# count  12032.000000  11420.000000  11420.000000  11420.000000  11420.000000
# mean      16.284163      9.438188      5.889809     21.605734      9.268025
# ...

# %%
# This gives the names of all the columns
stock_df.columns
# Out:
# Index(['compiled from Yahoo! Finance data by Matt Borthwick', 'ED', 'DD',
#        'CVX', 'FL', 'CAT', 'IP', 'SJW', 'F', 'LLY',
#        ...
#        'EXTN', 'VYGR', 'ACG', 'MIME', 'TCRZ', 'MCX', 'EDIT', 'LMHA', 'UA',
#        'BTU'],
#       dtype='object', length=711)

# %%
#Rename the first column of the data
stock_df.rename(columns={'compiled from Yahoo! Finance data by Matt Borthwick': 'date'},inplace=True)
stock_df["date"]
stock_df.head()
# Out:
#        date        ED        DD       CVX        FL       CAT        IP  SJW  \
# 0  1/2/1970  0.307997  0.000480  0.582503  1.857836  1.475225  1.808415  NaN
# 1  1/5/1970  0.320831  0.000481  0.585290  1.839623  1.470783  1.873423  NaN
# 2  1/6/1970  0.316553  0.000477  0.576929  1.845694  1.435234  1.855694  NaN
# 3  1/7/1970  0.312275  0.000475  0.575535  1.809266  1.390800  1.814324  NaN
# 4  1/8/1970  0.312275  0.000469  0.586683  1.821408  1.395244  1.832054  NaN
#
#     F  LLY ...   EXTN  VYGR  ACG  MIME  TCRZ  MCX  EDIT  LMHA  UA  BTU
# 0 NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
# 1 NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
# 2 NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
# 3 NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
# 4 NaN  NaN ...    NaN   NaN  NaN   NaN   NaN  NaN   NaN   NaN NaN  NaN
#
# [5 rows x 711 columns]

# %%
stock_df.tail()
# Out:
#            date         ED         DD         CVX         FL         CAT  \
# 12027  9/1/2017  83.989998        NaN  108.760002  36.340000  118.279999
# 12028  9/5/2017  84.370003  44.799999  109.440002  36.330002  118.300003
# 12029  9/6/2017  84.050003  44.849998  111.790001  36.700001  116.980003
# 12030  9/7/2017  84.739998  44.099998  111.800003  36.160000  117.769997
# 12031  9/8/2017  85.529999  43.500000  110.779999  35.730000  117.820000
#
#               IP        SJW      F        LLY    ...           EXTN   VYGR  \
# 12027  54.910000  55.080002  11.35  80.080002    ...      27.490000   9.96
# 12028  54.790001  55.720001  11.36  79.820000    ...      27.820000  10.93
# 12029  54.880001  55.900002  11.50  80.510002    ...      27.969999  13.63
# 12030  54.689999  56.360001  11.40  81.540001    ...      28.650000  14.37
# 12031  54.779999  56.709999  11.36  82.919998    ...      28.240000  14.59
#
# ...

# %%
# Shape gives the number of rows and columns; basically the shape of the table
stock_df.shape
# Out:
# (12032, 711)

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=12032, step=1)

# %%
#lets now answer soem questions
#1. Find stocks that lasted rom beginning to end: how many were those
#2. What was the growth of these stocks over the years
#3. When did these stocks see the largest growth
#4.

# %%
allyears_stockdf= stock_df.describe()
#allyears_stockdf.index
#allyears_stockdf[count > 11420]
#stock_df.transform("count") > 11000

# %%
# convert date to datetime
stock_df["date"].dtype
#stock_df["date"] =  pd.to_datetime(stock_df["date"], format = "%Y-%m-%d")
stock_df["date"] =  pd.to_datetime(stock_df["date"])
stock_df["date"].head()
#stock_df["date"].tail()
# Shows that data was collected from 1970 to 2017
# Out:
# 0   1970-01-02
# 1   1970-01-05
# 2   1970-01-06
# 3   1970-01-07
# 4   1970-01-08
# Name: date, dtype: datetime64[ns]

# %%
stock_df["date"].dt.year.value_counts(sort= False).plot.bar()
plt.show()
#stock_df["Date"].head()

# %%
# This will show how many rows there are for each stock; If there are only a few rows then we know
# the compnay did not exist for some number of years

for column in stock_df.columns:
    print(stock_df[column].count())
# Out:
# 12032
# 12032
# 12031
# 12032
# 12032
# 12032
# 12032
# 11420
# 11420
# 11420
# 11420
# 11190
# 11190
# 11190
# 11190
# 10879
# 10263
# 10263
# 10263
# 10263
# 9666
# 9454
# 9454
# 9454
# 9454
# 9422
# 9454
# 9454
# 9454
# 9454
# 9454
# 9355
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9452
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9454
# 9453
# 9454
# 9454
# 9454
# 9448
# 9445
# 9418
# 9403
# 9293
# 9274
# 9196
# 8259
# 9171
# 9001
# 9001
# 9001
# 9001
# 9001
# 9000
# 9001
# 9001
# 9000
# 8941
# 8755
# 8684
# 8681
# 8678
# 8671
# 8662
# 8601
# 8582
# 8563
# 8356
# 8331
# 8321
# 8182
# 8116
# 8102
# 8089
# 8017
# 8013
# 7936
# 7940
# 7889
# 7887
# 7848
# 7845
# 7804
# 7774
# 7747
# 7746
# 7693
# 7683
# 7659
# 7654
# 7651
# 7641
# 7640
# 7628
# 7626
# 7624
# 7596
# 7558
# 7543
# 7543
# 7522
# 7522
# ...

# %%
#Lets try and split the DF  based on years: 1970-1979,1980-1989, 1990-1999, 2000-2009, 2010-2017
curyear = stock_df['date'].dt.year
#print (curyear)
#print (stock_df["date"].dt.year)

mybins = [1969, 1979, 1989, 1999, 2009, 2019]
mylabels = ['seventies', 'eighties', 'nineties', 'twothousands', 'twothousandtens']

#for column in stock_df.columns:
   # z = stock_df.groupby(pd.cut(stock_df['date'], mybins, labels=mylabels )).column
#df[] = pd.cut(stock_df['date'], bins, labels = labels)

stock_df["year"]= stock_df["date"].dt.year
stock_df.head()
gb = stock_df.groupby('year').mean()
#[gb.get_group(x) for x in gb.groups]
print (gb.head())
# Out:
#             ED        DD       CVX        FL       CAT        IP       SJW  \
# year
# 1970  0.290380  0.000520  0.527082  1.640837  1.312917  1.661145       NaN
# 1971  0.325086  0.000686  0.681819  2.471132  1.724186  1.766956       NaN
# 1972  0.336633  0.000831  0.823214  1.996451  2.076578  1.948825  0.511213
# 1973  0.327159  0.000871  0.979936  1.236930  2.278732  2.263714  0.558310
# 1974  0.171693  0.000747  0.742835  0.829783  1.967395  2.548015  0.483624
#
#              F       LLY       AVP ...   EXTN  VYGR  ACG  MIME  TCRZ  MCX  \
# year                               ...
# 1970       NaN       NaN       NaN ...    NaN   NaN  NaN   NaN   NaN  NaN
# 1971       NaN       NaN       NaN ...    NaN   NaN  NaN   NaN   NaN  NaN
# 1972  0.338260  1.149024  2.019887 ...    NaN   NaN  NaN   NaN   NaN  NaN
# 1973  0.300681  1.292010  1.897609 ...    NaN   NaN  NaN   NaN   NaN  NaN
# 1974  0.237113  1.110930  0.666395 ...    NaN   NaN  NaN   NaN   NaN  NaN
#
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 8)
#for column in gb.columns:
    #ax = sns.countplot(y = gb[column], data = gb, x =gb.index)
gb.plot()
plt.show()

# %%
# ALL cells below this do NOT work; Need to fix

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 8)
for column in stock_df.columns:
    ax = sns.countplot(y = stock_df[column], data=stock_df)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-73200db3b6b7> in <module>()
#       3 for column in stock_df.columns:
#       4     ax = sns.countplot(y = stock_df[column], data=stock_df)
# ----> 5     plt.show()
#
# C:\Users\Padma\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# C:\Users\Padma\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# C:\Users\Padma\Anaconda3\lib\site-packages\IPython\core\display.py in display(*objs, **kwargs)
# ...

# %%
#for column in stock_df.columns:
   # long_stocks = stock_df[stock_df[column].count() == 12032]
    #long_stocks

# %%
# This works

mylist = [2000,2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]
df2000 = stock_df[stock_df["date"].dt.year.isin (mylist)]
print (df2000)
#df2000["date"].dt.month.value_counts(sort = False).plot.bar()
#plt.show()
#df2000.head()
#plot.bar()

# %%
#Questions to answer from Matt

#1. "Do stocks go up from one day to the next more often than they go down from one day to the next?"

#2. "Is there some unusual price behavior around <choose a date like Jan 1, 2000 or Sep 11, 2001>?"

#3. Try to avoid vague or complex questions like, "How long should you hold a stock after you buy it?"
